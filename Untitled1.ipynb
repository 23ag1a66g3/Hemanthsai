# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot([1,2,3,4])
plt.show()

# %%
categories=['A','B','C']
values=[1,2,3]
plt.bar(categories,values)
plt.show()

# %%
x=np.array([6,9])
y=np.array([6,9])
plt.plot( x,y)
plt.show()
