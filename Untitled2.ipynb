# %% [markdown]
# <a href="https://colab.research.google.com/github/23ag1a66g3/Hemanthsai/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#sample data
x=[1,2,3,4,5]
y=[5,7,4,8,6]
#create scatter plot
plt.scatter(x,y)
plt.xlabel('X values')
plt.ylabel('Y values')
plt.title('Simple Scatter Plot Example')
plt.show()

# %%
#sample data
labels=['a','b','c','d','e']
sizes=[15,32,18,17,18]
colors=['white','lightgreen','orange','pink','skyblue']
#create pie chart
plt.pie(sizes,colors=colors, labels=labels,autopct='%1.1f%%',startangle=140)
plt.title('Simple Pie Chart Example')
plt.axis('equal')
plt.show()

# %%
import numpy as np

#sample data:10x10 matrix

data =np.random.rand(10,10)
#create heatmap
plt.imshow(data,cmap='viridis',interpolation='nearest')
plt.colorbar() #show color scale
plt.title('Simple Heatmap Example')
plt.show()
